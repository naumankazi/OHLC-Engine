# %%
import json
import pandas as pd
import datetime
from datetime import date, datetime
import plotly.graph_objects as go

# %%
with open('Stock List.json') as json_file:
    data = json.load(json_file)

data = pd.DataFrame(data)
data
# Out:
#         close      high      low    open symbol     volume                 id  \
# 0      129.41  133.6116  126.760  133.52   AAPL  143301887  HISTORICAL_PRICES
# 1      131.01  131.7400  128.430  128.89   AAPL   97664898  HISTORICAL_PRICES
# 2      126.60  131.0499  126.382  127.72   AAPL  155087970  HISTORICAL_PRICES
# 3      130.92  131.6300  127.860  128.36   AAPL  109578157  HISTORICAL_PRICES
# 4      132.05  132.6300  130.230  132.43   AAPL  105158245  HISTORICAL_PRICES
# ...       ...       ...      ...     ...    ...        ...                ...
# 16619   70.86   72.5450   70.400   70.50   SNAP    8874468  HISTORICAL_PRICES
# 16620   72.72   72.9699   70.800   71.20   SNAP    8615044  HISTORICAL_PRICES
# 16621   75.50   75.9300   73.670   74.01   SNAP   11055928  HISTORICAL_PRICES
# 16622   74.63   76.3700   73.720   75.82   SNAP    9663823  HISTORICAL_PRICES
# 16623   74.69   74.9760   73.490   74.31   SNAP    7901376  HISTORICAL_PRICES
#
# ...

# %%
data.to_csv('stocklist.csv', index=False)

# %%
data = pd.read_csv('stocklist.csv')
data
# Out:
#         close      high      low    open symbol     volume                 id  \
# 0      129.41  133.6116  126.760  133.52   AAPL  143301887  HISTORICAL_PRICES
# 1      131.01  131.7400  128.430  128.89   AAPL   97664898  HISTORICAL_PRICES
# 2      126.60  131.0499  126.382  127.72   AAPL  155087970  HISTORICAL_PRICES
# 3      130.92  131.6300  127.860  128.36   AAPL  109578157  HISTORICAL_PRICES
# 4      132.05  132.6300  130.230  132.43   AAPL  105158245  HISTORICAL_PRICES
# ...       ...       ...      ...     ...    ...        ...                ...
# 16619   70.86   72.5450   70.400   70.50   SNAP    8874468  HISTORICAL_PRICES
# 16620   72.72   72.9699   70.800   71.20   SNAP    8615044  HISTORICAL_PRICES
# 16621   75.50   75.9300   73.670   74.01   SNAP   11055928  HISTORICAL_PRICES
# 16622   74.63   76.3700   73.720   75.82   SNAP    9663823  HISTORICAL_PRICES
# 16623   74.69   74.9760   73.490   74.31   SNAP    7901376  HISTORICAL_PRICES
#
# ...

# %%
data = data.drop(columns=['id', 'subkey'])
column = data.columns[:8]
column
columns = []
for i in [4, 3, 1, 2, 0, 5, 7, 6]:
    columns.append(column[i])
columns
# Out:
# ['symbol', 'open', 'high', 'low', 'close', 'volume', 'date', 'key']

# %%
Data = pd.DataFrame(data.iloc[:, :8].values)
Data.columns = column
Data
# Out:
#         close      high      low    open symbol     volume   key        date
# 0      129.41  133.6116   126.76  133.52   AAPL  143301887  AAPL  2021-01-04
# 1      131.01    131.74   128.43  128.89   AAPL   97664898  AAPL  2021-01-05
# 2       126.6  131.0499  126.382  127.72   AAPL  155087970  AAPL  2021-01-06
# 3      130.92    131.63   127.86  128.36   AAPL  109578157  AAPL  2021-01-07
# 4      132.05    132.63   130.23  132.43   AAPL  105158245  AAPL  2021-01-08
# ...       ...       ...      ...     ...    ...        ...   ...         ...
# 16619   70.86    72.545     70.4    70.5   SNAP    8874468  SNAP  2021-08-19
# 16620   72.72   72.9699     70.8    71.2   SNAP    8615044  SNAP  2021-08-20
# 16621    75.5     75.93    73.67   74.01   SNAP   11055928  SNAP  2021-08-23
# 16622   74.63     76.37    73.72   75.82   SNAP    9663823  SNAP  2021-08-24
# 16623   74.69    74.976    73.49   74.31   SNAP    7901376  SNAP  2021-08-25
#
# [16624 rows x 8 columns]

# %%
info = {}
for i in range(7):
    info[columns[i]] = Data[columns[i]]
info = pd.DataFrame(info)
info
# info.to_csv('info.csv', index=False)
# Out:
#       symbol    open      high      low   close     volume        date
# 0       AAPL  133.52  133.6116   126.76  129.41  143301887  2021-01-04
# 1       AAPL  128.89    131.74   128.43  131.01   97664898  2021-01-05
# 2       AAPL  127.72  131.0499  126.382   126.6  155087970  2021-01-06
# 3       AAPL  128.36    131.63   127.86  130.92  109578157  2021-01-07
# 4       AAPL  132.43    132.63   130.23  132.05  105158245  2021-01-08
# ...      ...     ...       ...      ...     ...        ...         ...
# 16619   SNAP    70.5    72.545     70.4   70.86    8874468  2021-08-19
# 16620   SNAP    71.2   72.9699     70.8   72.72    8615044  2021-08-20
# 16621   SNAP   74.01     75.93    73.67    75.5   11055928  2021-08-23
# 16622   SNAP   75.82     76.37    73.72   74.63    9663823  2021-08-24
# 16623   SNAP   74.31    74.976    73.49   74.69    7901376  2021-08-25
#
# [16624 rows x 7 columns]

# %%
i = 7
key = {}

key[columns[i]] = Data[columns[i]]
key = pd.DataFrame(key)
key
# key.to_csv('key.csv', index=False)
# Out:
#         key
# 0      AAPL
# 1      AAPL
# 2      AAPL
# 3      AAPL
# 4      AAPL
# ...     ...
# 16619  SNAP
# 16620  SNAP
# 16621  SNAP
# 16622  SNAP
# 16623  SNAP
#
# [16624 rows x 1 columns]
